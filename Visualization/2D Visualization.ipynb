# %% [markdown]
# ### I created a simple graph using math and matplotlip modules in Python. It helps in indroducing the plotting concepts, I hope you find it useful = )!

# %%
import math
import matplotlib.pyplot as plt
a = [1,2,3,4]
b = [math.pi, 322, 541,2]
plt.plot(a,b)
plt.show()
